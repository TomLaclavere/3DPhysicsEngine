# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("altitude.csv")

# %%
plt.figure(figsize=(8,6))

plt.plot(df["time"], df["pos"])
plt.xlabel("time (s)")
plt.ylabel("Altitude (m)")
# Out:
# Text(0, 0.5, 'Altitude (m)')
