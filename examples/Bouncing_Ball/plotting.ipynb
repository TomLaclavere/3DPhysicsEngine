# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent))

from utilities.motion_utilities import MotionCSV

# %%
motionCSV = MotionCSV("motion_object_0.csv")

# %%
motionCSV.plot_position_z()
