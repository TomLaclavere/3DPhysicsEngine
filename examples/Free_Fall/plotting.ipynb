# %%
import sys
import glob
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent))

from utilities.motion_utilities import MotionCSVManager

# %%
filepaths = glob.glob("*.csv")
motionCSV = MotionCSVManager(filepaths)

# %%
motionCSV.plot_positions_z_all()
