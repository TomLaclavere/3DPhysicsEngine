# %%
import glob
import sys
sys.path.append("../..")
from python.utilities.motion_utilities import MotionPlotting
from python.utilities.object_utilities import ObjectPlotting

# %%
motionpaths = glob.glob("CSV/motion_*.csv")
objectpath = "CSV/objects.csv"
motionPlot = MotionPlotting(objectpath, motionpaths)
objectPlot = ObjectPlotting(objectpath, motionpaths)
# Out:
#    id           name    type  mass  pos(x)  pos(y)  pos(z)  size(x)  size(y)  \
# 0   0  Bouncing Ball  Sphere     1       0       0      20      0.2      0.2
# 1   1         Ground   Plane     0       0       0       0      5.0      5.0
#
#    size(z)  fixed
# 0      0.2      0
# 1      0.0      1
# Nombre d'objets : 2

# %%
motionPlot.plot_positions_z()

# %%
objectPlot.animate_objects(stride=50)
