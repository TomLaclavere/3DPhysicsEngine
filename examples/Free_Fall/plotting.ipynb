# %%
import glob
import sys
sys.path.append("../..")
from python.utilities.motion_utilities import MotionPlotting

# %%
motionpaths = glob.glob("CSV/motion_*.csv")
objectpath = "CSV/objects.csv"
motionCSV = MotionPlotting(objectpath, motionpaths)
# Out:
# Sphere
# Plane
# Cube
# ground

# %%
motionCSV.plot_positions_z()
