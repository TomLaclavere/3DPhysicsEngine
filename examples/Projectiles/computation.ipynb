# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent))

from utilities.computation_utilities import Object, SecondOrderEq
import numpy as np

# %%
g = np.array([0, 0, -9.81])

# %%
sphere = Object(pos=[0, 0, 1.5], vel=[1000, 0, 0], collision_condition=[0, 0, 0.2/2],g=g)
plane = Object(pos=[10, 0, 1], vel=[0, 0, 100], collision_condition=[0, 0, 0.2],g=g)
cube = Object(pos=[0, 10, 1], vel=[0, 50, 50], collision_condition=[0, 0, 0.1/np.sqrt(2)],g=g)

# %%
print("Sphere : ", SecondOrderEq(*sphere.get_eq()).get_time_contact_ground(), " s")
print("Final position :", SecondOrderEq(*sphere.get_eq()).get_distance_at_contact_ground(), " m\n")
# Out:
# Sphere :  0.5342499768054424  s
# Final position : [ 5.34249977e+02  0.00000000e+00 -4.44089210e-16]  m

# %%
print("Plane : ", SecondOrderEq(*plane.get_eq()).get_time_contact_ground(), " s")
print("Final position :", SecondOrderEq(*plane.get_eq()).get_distance_at_contact_ground(), " m\n")
# Out:
# Plane :  20.39535670016235  s
# Final position : [1.0000000e+01 0.0000000e+00 4.5519144e-14]  m

# %%
print("Cube : ", SecondOrderEq(*cube.get_eq()).get_time_contact_ground(), " s")
print("Final position :", SecondOrderEq(*cube.get_eq()).get_distance_at_contact_ground(), " m\n")
# Out:
# Cube :  10.212231941071188  s
# Final position : [ 0.00000000e+00  5.20611597e+02 -1.07691633e-14]  m
