# %%
import glob
import sys
sys.path.append("../..")
from python.utilities.motion_utilities import MotionCSVManager

# %%
motionpaths = glob.glob("CSV/motion_*.csv")
objectpath = "CSV/objects.csv"
motionCSV = MotionCSVManager(objectpath, motionpaths)
# Out:
# Bouncing Ball
# Ground 1
# Ground 2

# %%
motionCSV.plot_positions_z()

# %%
motionCSV.plot_positions()
